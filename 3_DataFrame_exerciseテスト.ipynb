# %% [markdown]
# <a href="https://colab.research.google.com/github/ganonononon/Kaggke_Udemy/blob/main/3_DataFrame_exercise%E3%83%86%E3%82%B9%E3%83%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # 3.DataFrame Exercise
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Exercise_1 : 'sample1_with_index.csv'を読み込んでデータフレーム（df）を作成して下さい。その際にindexにカラムインデックス0のデータを割り当ててください (google colaboratoryの場合は、ドライブのマウントを行ってください。ファイルパスは '/drive/My Drive/sample1_with_index.csv)

# %%
df = pd.read_csv('/content/drive/MyDrive/kaggle_udemy/udemy_course/sample1_with_index.csv',index_col=0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df = pd.read_csv('sample1_with_index.csv', index_col=0)</code>
# </details>

# %%
# 実行して表示
df.head(3)
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 0  1997-07-05   2291        25  2.946650  5.305868  45.893300  52.762659
# 1  1997-07-06    506        16  1.915208  0.679004  50.611735  31.453719
# 2  1997-07-07   9629        32  7.869855  6.563335  43.830416  56.239011
#
#    Difference  Color     Shape
# 0    0.276266  green  triangle
# 1   -1.854628   blue       NaN
# 2    0.623901   blue    square

# %% [markdown]
# Exercise_2 : 重複行としてインデックス5,6,7,8のレコードをdfに追加してください。その後、インデックスをリセットしてください。

# %%
# 追加
df = pd.concat([df, df.loc[5:8]])

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df = df.append(df.loc[5:8])</code>
# </details>

# %%
# インデックスをリセット
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.reset_index(drop=True, inplace=True)</code>
# </details>

# %%
# 実行して表示
df.tail()
# Out:
#            Date  Price  Quantity     Width    Height    Quality      Score  \
# 99   1997-10-12   1578        77  9.868106  5.397452  56.472400        NaN
# 100  1997-07-10   9347        32  9.456832  0.600447  53.126670  68.866389
# 101  1997-07-11   3723        41  8.640421  8.772905  52.750418  48.883017
# 102  1997-07-12   4664        78  0.511937  6.524186  51.512058  46.378987
# 103  1997-07-13   3045        49  5.517514  5.975133  40.781258  51.486750
#
#      Difference  Color     Shape
# 99     2.215901    red       NaN
# 100    1.886639  green  triangle
# 101   -0.111698   blue    circle
# 102   -0.362101    red    square
# 103    0.148675    red  triangle

# %% [markdown]
# Exercise_3 : 現在object型になっている'Date'をdatetime型に変換してください

# %%
# 実行して表示
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        101 non-null    object
#  1   Price       104 non-null    int64
#  2   Quantity    104 non-null    int64
#  3   Width       101 non-null    float64
#  4   Height      101 non-null    float64
#  5   Quality     100 non-null    float64
#  6   Score       97 non-null     float64
#  7   Difference  103 non-null    float64
#  8   Color       100 non-null    object
#  9   Shape       99 non-null     object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 8.3+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df['Date'] = pd.to_datetime(df['Date'])</code>
# </details>

# %%
# 実行して表示
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        101 non-null    datetime64[ns]
#  1   Price       104 non-null    int64
#  2   Quantity    104 non-null    int64
#  3   Width       101 non-null    float64
#  4   Height      101 non-null    float64
#  5   Quality     100 non-null    float64
#  6   Score       97 non-null     float64
#  7   Difference  103 non-null    float64
#  8   Color       100 non-null    object
#  9   Shape       99 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 8.3+ KB

# %% [markdown]
# Exercise_4 : 'Price'の先頭の5行をデータフレーム形式で表示してください。

# %%
df[['Price']].head()
# Out:
#    Price
# 0   2291
# 1    506
# 2   9629
# 3   6161
# 4   8570

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df[['Price']].head()</code>
# </details>

# %% [markdown]
# Exercise_5 : locを用いてindex15～20、'Width'から'Difference'の値を表示してください

# %%
df.loc[15:20, 'Width':'Difference']
# Out:
#        Width    Height    Quality      Score  Difference
# 15  1.987739  8.313639  53.048372        NaN   -1.775282
# 16  5.679911  0.823397  51.035027  63.148765    1.314877
# 17  5.449986  1.589587  51.950265  45.265520   -0.473448
# 18  6.767624  1.184723  49.670572  39.077701   -1.092230
# 19  4.449961  8.879824  45.659763  47.499726   -0.250027
# 20  7.972677  0.679787  45.954514  40.177057   -0.982294

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.loc[15:20, 'Width':'Difference']</code>
# </details>

# %% [markdown]
# Exercise_6 : インデックスが40～45、カラムのindexが 2,4,6 の値を表示してください

# %%
df.iloc[40:46, [2, 4, 6]]
# Out:
#     Quantity    Height      Score
# 40        18  2.453724  38.445867
# 41        61  0.641278  83.451574
# 42        37  4.876773  51.267272
# 43        97  1.061689  43.058211
# 44        73  9.603458  55.576744
# 45        36  5.698250  50.991466

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.iloc[40:46, [2, 4, 6]]</code>
# </details>

# %% [markdown]
# Exercise_7 : 'Difference'の値が2より大きいか、もしくは-2より小さいもののレコードを表示してください

# %%
df[(df['Difference'] > 2) | (df['Difference'] < -2)]
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 10 1997-07-15   5916        54  2.977257  5.615089  58.913664  71.712570
# 39 1997-08-13    535        70  7.850837  3.532813  57.759649  29.640052
# 41 1997-08-15   4063        61  7.274125  0.641278  41.359575  83.451574
# 63 1997-09-06    975        93  1.885842  7.820278  41.666508  20.398774
# 68 1997-09-11   1991        27  5.854357  5.830665  57.440876  77.207956
# 86 1997-09-29   7975        24  2.049086  3.255184  52.817497  72.070163
# 87 1997-09-30   8538        34  5.016090  8.783188  42.123377  16.000692
# 92 1997-10-05   8057        60  5.927891  0.157152        NaN  78.711269
# 99 1997-10-12   1578        77  9.868106  5.397452  56.472400        NaN
#
#     Difference  Color     Shape
# 10    2.171257  green       NaN
# 39   -2.035995   blue    square
# 41    3.345157    red       NaN
# 63   -2.960123  green    square
# 68    2.720796  green    circle
# 86    2.207016    red    circle
# 87   -3.399931   blue  triangle
# 92    2.871127   blue    square
# 99    2.215901    red       NaN

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df[(df['Difference'] > 2) | (df['Difference'] < -2)]</code>
# </details>

# %% [markdown]
# Exercise_8: インデックスが17と19の'Color'の値をともに'purple'に、また'Difference'の値をそれぞれ0.111と0.888に更新してください

# %%
df.loc[[17, 19],['Color', 'Difference']] = [['purple', 0.111],['purple', 0.888]]

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.loc[[17, 19], ['Color', 'Difference']] = [['purple', 0.111], ['purple', 0.888]]</code>
# </details>

# %%
# 実行して表示
df.loc[[17, 19]]
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 17 1997-07-22   8255        13  5.449986  1.589587  51.950265  45.265520
# 19 1997-07-24   4893        16  4.449961  8.879824  45.659763  47.499726
#
#     Difference   Color     Shape
# 17       0.111  purple  triangle
# 19       0.888  purple    circle

# %% [markdown]
# Exercise_9 : カラム名に 'ty' を含むカラムのインデックス100の値を表示してください

# %%
df.filter(like='ty', axis=1).loc[100]
# Out:
# Quantity    32.00000
# Quality     53.12667
# Name: 100, dtype: float64

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.filter(like='ty', axis=1).loc[100]</code>
# </details>

# %% [markdown]
# Exercise_10 : queryを使い、'Shape'が'circle'もしくは'triangle'、かつ'Score'が70以上のレコードを表示してください

# %%
df.query("Shape in ['circle','triangle'] & Score >= 70")
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 68 1997-09-11   1991        27  5.854357  5.830665  57.440876  77.207956
# 86 1997-09-29   7975        24  2.049086  3.255184  52.817497  72.070163
#
#     Difference  Color   Shape
# 68    2.720796  green  circle
# 86    2.207016    red  circle

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.query("Shape in ['circle', 'triangle'] & Score >=70")</code>
# </details>

# %% [markdown]
# Exercise_11: 各カラムの基本統計量を表示してください

# %%
df.describe()
# Out:
#                                 Date        Price    Quantity       Width  \
# count                            101   104.000000  104.000000  101.000000
# mean   1997-08-22 04:02:22.574257408  4776.125000   50.134615    5.201116
# min              1997-07-05 00:00:00   266.000000   11.000000    0.369691
# 25%              1997-07-27 00:00:00  2644.750000   27.750000    2.610089
# 50%              1997-08-22 00:00:00  4496.000000   51.000000    5.156806
# 75%              1997-09-16 00:00:00  7327.750000   67.500000    7.769746
# max              1997-10-12 00:00:00  9991.000000   99.000000    9.880067
# std                              NaN  2674.479358   24.523046    2.808132
#
#            Height     Quality      Score  Difference
# count  101.000000  100.000000  97.000000  103.000000
# mean     5.161020   50.019550  51.140900    0.133952
# min      0.137159   40.313924  16.000692   -3.399931
# 25%      2.324704   44.296750  43.899300   -0.614234
# 50%      5.698250   51.132603  51.267272    0.131268
# 75%      7.820278   54.994604  57.031107    0.803171
# max      9.843835   59.687671  83.451574    3.345157
# std      3.006784    5.910680  11.036527    1.123906

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.describe()</code>
# </details>

# %% [markdown]
# Exercise_12 : 'Shape'に存在するユニークな値の数、その値を全て含むアレイ、またそれぞれの値のカウントを表示してください

# %%
# ユニークな値はいくつあるか
df['Shape'].nunique()

# !!!
# nunique()には nan は数として含まれません！！！
# !!!
# Out:
# 3

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df['Shape'].nunique()</code>
# </details>

# %%
# ユニークな値のアレイ
df['Shape'].unique()
# Out:
# array(['triangle', nan, 'square', 'circle'], dtype=object)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df['Shape'].unique()</code>
# </details>

# %%
# それぞれの値の個数
df['Shape'].value_counts()
# Out:
# Shape
# square      35
# triangle    34
# circle      30
# Name: count, dtype: int64

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df['Shape'].value_counts()</code>
# </details>

# %% [markdown]
# Exercise_13 : 'Quality'の値の大きいもの3つのindexを取得し、それらの全データを表示してください

# %%
# 上位3つのindex
idxs = df['Quality'].nlargest(3).index

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>idxs = df['Quality'].nlargest(3).index</code>
# </details>

# %%
# 実行して表示
idxs
# Int64Index([57, 42, 89], dtype='int64')が表示されればOK
# Out:
# Index([57, 42, 89], dtype='int64')

# %%
# 実行して表示
df.iloc[idxs]
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 57 1997-08-31    639        30  9.479230  1.300150  59.687671  61.854042
# 42 1997-08-16   6307        37       NaN  4.876773  59.215755  51.267272
# 89 1997-10-02    860        20  8.438626  1.365645  59.206916  44.121192
#
#     Difference  Color     Shape
# 57    1.185404    red  triangle
# 42    0.126727  green    square
# 89   -0.587881    red    circle

# %% [markdown]
# Exercise_14 : 'Color'でグループ化し、その中のグループ'green'に属するデータの先頭5行を表示してください

# %%
df.groupby('Color').get_group('green').head()
# index 0, 3, 5, 10, 12のレコードが表示されればOK
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 0  1997-07-05   2291        25  2.946650  5.305868  45.893300  52.762659
# 3  1997-07-08   6161        67  6.375209  5.756029  41.358007  61.453113
# 5  1997-07-10   9347        32  9.456832  0.600447  53.126670  68.866389
# 10 1997-07-15   5916        54  2.977257  5.615089  58.913664  71.712570
# 12 1997-07-17   4678        11  4.184844  1.439039  57.280842  31.811877
#
#     Difference  Color     Shape
# 0     0.276266  green  triangle
# 3     1.145311  green    square
# 5     1.886639  green  triangle
# 10    2.171257  green       NaN
# 12   -1.818812  green  triangle

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.groupby('Color').get_group('green').head()</code>
# </details>

# %% [markdown]
# Exercise_15 :  'Color'でグループ化した'Price'と'Quantity'の統計量（平均と中央値）を表示してください（aggを使って）

# %%
df.groupby('Color')[['Price', 'Quantity']].agg(['mean', 'median'])
# Out:
#               Price           Quantity
#                mean  median       mean median
# Color
# blue    5033.000000  4629.0  51.971429   55.0
# green   4991.205882  5094.5  45.088235   42.5
# purple  6574.000000  6574.0  14.500000   14.5
# red     4138.666667  3711.0  55.700000   54.0

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.groupby('Color')[['Price', 'Quantity']].agg(['mean', 'median'])</code>
# </details>

# %% [markdown]
# Exercise_16 : 'Color'と'Shape'のふたつのクラスでグループ化し、その中の'red'と'square'に属するグループのレコードを表示してください。

# %%
# まずはグループを確認する
df.groupby(['Color', 'Shape']).groups
# Out:
# {('blue', 'circle'): [6, 11, 16, 31, 49, 50, 59, 75, 78, 85, 95, 98, 101], ('blue', 'square'): [2, 15, 21, 23, 30, 34, 38, 39, 71, 81, 82, 84, 92, 97], ('blue', 'triangle'): [18, 32, 44, 45, 48, 80, 87], ('blue', nan): [1], ('green', 'circle'): [28, 35, 68, 79, 88, 93], ('green', 'square'): [3, 20, 22, 26, 36, 42, 51, 58, 62, 63, 70, 72, 74], ('green', 'triangle'): [0, 5, 12, 13, 25, 29, 47, 53, 65, 67, 76, 77, 100], ('green', nan): [10, 24], ('purple', 'circle'): [19], ('purple', 'triangle'): [17], ('red', 'circle'): [9, 33, 46, 54, 56, 86, 89, 90, 91], ('red', 'square'): [4, 7, 27, 52, 60, 64, 94, 102], ('red', 'triangle'): [8, 14, 43, 55, 57, 61, 66, 69, 83, 96, 103], ('red', nan): [41, 99], (nan, 'circle'): [37], (nan, 'triangle'): [40, 73]}

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.groupby(['Color', 'Shape']).groups</code>
# </details>

# %%
# red, squareのグループを抽出する
df.groupby(['Color', 'Shape']).get_group(('red','square'))
# Out:
#           Date  Price  Quantity     Width    Height    Quality      Score  \
# 4          NaT   8570        55  0.390629  3.578136  55.739709        NaN
# 7   1997-07-12   4664        78  0.511937  6.524186  51.512058  46.378987
# 27  1997-08-01   5222        71  5.206351  4.928727  41.104827  51.599909
# 52  1997-08-26   1584        98  8.588621  3.105036  47.807490  52.445200
# 60  1997-09-03   3193        37  4.828547  5.407474  51.615497  47.696270
# 64  1997-09-07   3773        23  6.439261  4.853990  57.677284  42.044189
# 94  1997-10-07   9991        14  2.286239  1.898837  49.962874  60.036032
# 102 1997-07-12   4664        78  0.511937  6.524186  51.512058  46.378987
#
#      Difference Color   Shape
# 4      1.037190   red  square
# 7     -0.362101   red  square
# 27     0.159991   red  square
# 52     0.244520   red  square
# 60    -0.230373   red  square
# 64    -0.795581   red  square
# 94     1.003603   red  square
# 102   -0.362101   red  square

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.groupby(['Color', 'Shape']).get_group(('red','square'))</code>
# </details>

# %% [markdown]
# Exercise_17 : 下記のdf_Dにおいて'Shape'が'triangle'である行だけを表示してください

# %%
# 実行して表示
df_D = df.groupby(['Color', 'Shape']).describe()
df_D
# Out:
#                  Date                                                      \
#                 count                           mean                  min
# Color  Shape
# blue   circle      13  1997-08-24 16:36:55.384615424  1997-07-11 00:00:00
#        square      13  1997-08-22 05:32:18.461538432  1997-07-07 00:00:00
#        triangle     7  1997-08-24 13:42:51.428571392  1997-07-23 00:00:00
# green  circle       6            1997-09-08 04:00:00  1997-08-02 00:00:00
#        square      13  1997-08-20 01:50:46.153846144  1997-07-08 00:00:00
#        triangle    12            1997-08-11 10:00:00  1997-07-05 00:00:00
# purple circle       1            1997-07-24 00:00:00  1997-07-24 00:00:00
#        triangle     1            1997-07-22 00:00:00  1997-07-22 00:00:00
# red    circle       9            1997-09-04 13:20:00  1997-07-14 00:00:00
#        square       7  1997-08-18 10:17:08.571428608  1997-07-12 00:00:00
#        triangle    11  1997-08-24 21:49:05.454545408  1997-07-13 00:00:00
#
#                                                            \
#                                  25%                  50%
# Color  Shape
# blue   circle    1997-07-21 00:00:00  1997-08-24 00:00:00
#        square    1997-07-28 00:00:00  1997-08-12 00:00:00
#        triangle  1997-08-12 00:00:00  1997-08-19 00:00:00
# green  circle    1997-08-17 06:00:00  1997-09-16 12:00:00
#        square    1997-07-31 00:00:00  1997-08-25 00:00:00
#        triangle  1997-07-15 06:00:00  1997-08-12 00:00:00
# purple circle    1997-07-24 00:00:00  1997-07-24 00:00:00
#        triangle  1997-07-22 00:00:00  1997-07-22 00:00:00
# red    circle    1997-08-20 00:00:00  1997-08-30 00:00:00
#        square    1997-07-22 00:00:00  1997-08-26 00:00:00
#        triangle  1997-08-02 12:00:00  1997-08-31 00:00:00
#
#                                                                Price  \
#                                  75%                  max  std count
# Color  Shape
# blue   circle    1997-09-21 00:00:00  1997-10-11 00:00:00  NaN  13.0
#        square    1997-09-24 00:00:00  1997-10-10 00:00:00  NaN  14.0
#        triangle  1997-09-07 00:00:00  1997-09-30 00:00:00  NaN   7.0
# green  circle    1997-09-28 18:00:00  1997-10-06 00:00:00  NaN   6.0
#        square    1997-09-06 00:00:00  1997-09-17 00:00:00  NaN  13.0
#        triangle  1997-09-08 12:00:00  1997-09-20 00:00:00  NaN  13.0
# purple circle    1997-07-24 00:00:00  1997-07-24 00:00:00  NaN   1.0
#        triangle  1997-07-22 00:00:00  1997-07-22 00:00:00  NaN   1.0
# red    circle    1997-10-02 00:00:00  1997-10-04 00:00:00  NaN   9.0
#        square    1997-09-05 00:00:00  1997-10-07 00:00:00  NaN   8.0
#        triangle  1997-09-10 12:00:00  1997-10-09 00:00:00  NaN  11.0
#
#                               ...      Score            Difference            \
#                         mean  ...        max        std      count      mean
# Color  Shape                  ...
# blue   circle    5091.769231  ...  63.148765   8.131852       13.0  0.323656
#        square    5464.428571  ...  78.711269  12.237765       14.0  0.159002
#        triangle  4707.714286  ...  55.576744  13.182771        7.0 -0.724887
# green  circle    4177.000000  ...  77.207956  15.514541        6.0  0.485319
#        square    5438.076923  ...  61.453113  11.080823       13.0 -0.382628
#        triangle  5065.230769  ...  68.866389  10.477463       13.0  0.311317
# purple circle    4893.000000  ...  47.499726        NaN        1.0  0.888000
#        triangle  8255.000000  ...  45.265520        NaN        1.0  0.111000
# red    circle    3170.111111  ...  72.070163   9.623098        8.0  0.099071
#        square    5207.625000  ...  60.036032   5.808254        8.0  0.086893
#        triangle  4393.363636  ...  61.854042   5.035193       11.0  0.263675
#
#
#                       min       25%       50%       75%       max       std
# Color  Shape
# blue   circle   -0.786014 -0.138585 -0.111698  1.130726  1.314877  0.781689
#        square   -2.035995 -0.575460  0.340590  0.959691  2.871127  1.300911
#        triangle -3.399931 -1.004162 -0.426631  0.101501  0.557674  1.318277
# green  circle   -1.208086 -0.553598  0.460451  1.142553  2.720796  1.435257
#        square   -2.960123 -0.982294 -0.710834  0.491334  1.145311  1.108082
#        triangle -1.818812 -0.138049  0.276266  0.703111  1.886639  1.038383
# purple circle    0.888000  0.888000  0.888000  0.888000  0.888000       NaN
#        triangle  0.111000  0.111000  0.111000  0.111000  0.111000       NaN
# red    circle   -0.976937 -0.593428 -0.068596  0.439191  2.207016  1.010673
#        square   -0.795581 -0.362101 -0.035191  0.434291  1.037190  0.660760
#        triangle -1.040172  0.134435  0.522537  0.585524  1.185404  0.644345
#
# [11 rows x 64 columns]

# %%
# 実行して表示
df_D.index
# Out:
# MultiIndex([(  'blue',   'circle'),
#             (  'blue',   'square'),
#             (  'blue', 'triangle'),
#             ( 'green',   'circle'),
#             ( 'green',   'square'),
#             ( 'green', 'triangle'),
#             ('purple',   'circle'),
#             ('purple', 'triangle'),
#             (   'red',   'circle'),
#             (   'red',   'square'),
#             (   'red', 'triangle')],
#            names=['Color', 'Shape'])

# %%
# 回りくどいですが、条件をconditionに指定してください
condition = df_D.index.get_level_values('Shape') == 'triangle'

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>condition = df_D.index.get_level_values('Shape') == 'triangle'</code>
# </details>

# %%
# 実行して表示
df_D[condition]
# Out:
#                  Date                                                      \
#                 count                           mean                  min
# Color  Shape
# blue   triangle     7  1997-08-24 13:42:51.428571392  1997-07-23 00:00:00
# green  triangle    12            1997-08-11 10:00:00  1997-07-05 00:00:00
# purple triangle     1            1997-07-22 00:00:00  1997-07-22 00:00:00
# red    triangle    11  1997-08-24 21:49:05.454545408  1997-07-13 00:00:00
#
#                                                            \
#                                  25%                  50%
# Color  Shape
# blue   triangle  1997-08-12 00:00:00  1997-08-19 00:00:00
# green  triangle  1997-07-15 06:00:00  1997-08-12 00:00:00
# purple triangle  1997-07-22 00:00:00  1997-07-22 00:00:00
# red    triangle  1997-08-02 12:00:00  1997-08-31 00:00:00
#
#                                                                Price  \
#                                  75%                  max  std count
# Color  Shape
# blue   triangle  1997-09-07 00:00:00  1997-09-30 00:00:00  NaN   7.0
# green  triangle  1997-09-08 12:00:00  1997-09-20 00:00:00  NaN  13.0
# purple triangle  1997-07-22 00:00:00  1997-07-22 00:00:00  NaN   1.0
# red    triangle  1997-09-10 12:00:00  1997-10-09 00:00:00  NaN  11.0
#
#                               ...      Score            Difference            \
#                         mean  ...        max        std      count      mean
# Color  Shape                  ...
# blue   triangle  4707.714286  ...  55.576744  13.182771        7.0 -0.724887
# green  triangle  5065.230769  ...  68.866389  10.477463       13.0  0.311317
# purple triangle  8255.000000  ...  45.265520        NaN        1.0  0.111000
# red    triangle  4393.363636  ...  61.854042   5.035193       11.0  0.263675
#
#
#                       min       25%       50%       75%       max       std
# Color  Shape
# blue   triangle -3.399931 -1.004162 -0.426631  0.101501  0.557674  1.318277
# green  triangle -1.818812 -0.138049  0.276266  0.703111  1.886639  1.038383
# purple triangle  0.111000  0.111000  0.111000  0.111000  0.111000       NaN
# red    triangle -1.040172  0.134435  0.522537  0.585524  1.185404  0.644345
#
# [4 rows x 64 columns]

# %% [markdown]
# Exercise_18 : dfを'Color'に対して昇順、さらに'Quantity'に対して降順に並べ替えて表示してください。その際、nanを先頭に表示してください。

# %%
df_sorted = df.sort_values(by=['Color', 'Quantity'], ascending=[True, False], na_position='first')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df_sorted = df.sort_values(by=['Color', 'Quantity'], ascending=[True, False], na_position='first')</code>
# </details>

# %%
# 実行して表示
df_sorted
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 73 1997-09-16   6354        84  7.945283  7.917093  54.312865  56.844951
# 37 1997-08-11   4768        60  0.827355  6.754864  42.369445  54.652823
# 40 1997-08-14   2431        18  2.201921  2.453724  55.945355  38.445867
# 71 1997-09-14   6801        99  3.606084  1.688734  44.727623  49.963040
# 48 1997-08-22   4710        89  8.710470  7.130864  55.539492  40.839068
# ..        ...    ...       ...       ...       ...        ...        ...
# 86 1997-09-29   7975        24  2.049086  3.255184  52.817497  72.070163
# 33 1997-08-07   4479        23  7.955946  7.681904  41.646795  53.005910
# 64 1997-09-07   3773        23  6.439261  4.853990  57.677284  42.044189
# 89 1997-10-02    860        20  8.438626  1.365645  59.206916  44.121192
# 94 1997-10-07   9991        14  2.286239  1.898837  49.962874  60.036032
#
#     Difference Color     Shape
# 73    0.684495   NaN  triangle
# 37    0.465282   NaN    circle
# 40   -1.155413   NaN  triangle
# 71   -0.003696  blue    square
# 48   -0.916093  blue  triangle
# ..         ...   ...       ...
# 86    2.207016   red    circle
# 33    0.300591   red    circle
# 64   -0.795581   red    square
# 89   -0.587881   red    circle
# 94    1.003603   red    square
#
# [104 rows x 10 columns]

# %% [markdown]
# Exercise_19 : クロスセクション（xs）を使ってdf_Dの'Shape'が'triangle'であるレコードを抽出してください

# %%
# 重複行の数（sum）を確認
df_D.xs('triangle', level='Shape')
# Out:
#         Date                                                      \
#        count                           mean                  min
# Color
# blue       7  1997-08-24 13:42:51.428571392  1997-07-23 00:00:00
# green     12            1997-08-11 10:00:00  1997-07-05 00:00:00
# purple     1            1997-07-22 00:00:00  1997-07-22 00:00:00
# red       11  1997-08-24 21:49:05.454545408  1997-07-13 00:00:00
#
#                                                                        \
#                         25%                  50%                  75%
# Color
# blue    1997-08-12 00:00:00  1997-08-19 00:00:00  1997-09-07 00:00:00
# green   1997-07-15 06:00:00  1997-08-12 00:00:00  1997-09-08 12:00:00
# purple  1997-07-22 00:00:00  1997-07-22 00:00:00  1997-07-22 00:00:00
# red     1997-08-02 12:00:00  1997-08-31 00:00:00  1997-09-10 12:00:00
#
#                                  Price               ...      Score  \
#                         max  std count         mean  ...        max
# Color                                                ...
# blue    1997-09-30 00:00:00  NaN   7.0  4707.714286  ...  55.576744
# green   1997-09-20 00:00:00  NaN  13.0  5065.230769  ...  68.866389
# purple  1997-07-22 00:00:00  NaN   1.0  8255.000000  ...  45.265520
# red     1997-10-09 00:00:00  NaN  11.0  4393.363636  ...  61.854042
#
#                   Difference                                          \
#               std      count      mean       min       25%       50%
# Color
# blue    13.182771        7.0 -0.724887 -3.399931 -1.004162 -0.426631
# green   10.477463       13.0  0.311317 -1.818812 -0.138049  0.276266
# purple        NaN        1.0  0.111000  0.111000  0.111000  0.111000
# red      5.035193       11.0  0.263675 -1.040172  0.134435  0.522537
#
#
#              75%       max       std
# Color
# blue    0.101501  0.557674  1.318277
# green   0.703111  1.886639  1.038383
# purple  0.111000  0.111000       NaN
# red     0.585524  1.185404  0.644345
#
# [4 rows x 64 columns]

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df_D.xs('triangle', level='Shape')</code>
# </details>

# %% [markdown]
# Exercise_20 : dfの重複行の数を確認し、重複行を削除してください

# %%
# 重複行の数（sum）を確認
df.duplicated().sum()
# Out:
# 4

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.duplicated().sum()</code>
# </details>

# %%
# 削除
df.drop_duplicates(inplace=True)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.drop_duplicates(inplace=True)</code>
# </details>

# %%
# 実行して確認.100が表示されればOK
len(df)
# Out:
# 100

# %% [markdown]
# Exercise_21 : 条件に従って欠損値の処理を行ってください（dictionaryを使った方法です）

# %%
# 実行して表示
# 'Date'がnullのレコードを表示
df[df['Date'].isnull()]
# Out:
#    Date  Price  Quantity     Width    Height    Quality      Score  \
# 4   NaT   8570        55  0.390629  3.578136  55.739709        NaN
# 25  NaT   2977        59  8.293048  0.291570  42.878078  51.312678
# 82  NaT   4236        56  2.071701  9.561883  54.548250  50.572798
#
#     Difference  Color     Shape
# 4     1.037190    red    square
# 25    0.131268  green  triangle
# 82    0.057280   blue    square

# %%
# 'Date'がNaTのレコードを削除。subsetを利用します
df.dropna(subset=['Date'], inplace=True)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.dropna(subset=['Date'], inplace=True)</code><br>
# </details>

# %%
# 実行して表示
df[df['Date'].isnull()]
# レコードが表示されなければOK
# Out:
# Empty DataFrame
# Columns: [Date, Price, Quantity, Width, Height, Quality, Score, Difference, Color, Shape]
# Index: []

# %%
# 実行して表示
# 'Color'は'white'で、'Shape'は'ellipse'で、その他は平均値で置き換えます。
# そのためには置き換える値を指定するためのdictionaryが必要になります。
# ひとまずnanを持つレコードを表示します
df[df.isnull().sum(axis=1) > 0].style.highlight_null(color='#fcc') # null_colorをcolorに変更
# Out:
# <style type="text/css">
# #T_16e68_row0_col9, #T_16e68_row1_col4, #T_16e68_row2_col9, #T_16e68_row3_col6, #T_16e68_row4_col9, #T_16e68_row5_col3, #T_16e68_row6_col8, #T_16e68_row7_col8, #T_16e68_row8_col9, #T_16e68_row9_col3, #T_16e68_row10_col5, #T_16e68_row11_col7, #T_16e68_row12_col4, #T_16e68_row13_col6, #T_16e68_row14_col4, #T_16e68_row15_col5, #T_16e68_row16_col8, #T_16e68_row17_col6, #T_16e68_row18_col6, #T_16e68_row19_col3, #T_16e68_row20_col6, #T_16e68_row21_col5, #T_16e68_row22_col5, #T_16e68_row23_col6, #T_16e68_row23_col9 {
#   background-color: #fcc;
# }
# </style>
# <table id="T_16e68" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e68_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_16e68_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_16e68_level0_col2" class="col_heading level0 col2" >Quantity</th>
#       <th id="T_16e68_level0_col3" class="col_heading level0 col3" >Width</th>
#       <th id="T_16e68_level0_col4" class="col_heading level0 col4" >Height</th>
#       <th id="T_16e68_level0_col5" class="col_heading level0 col5" >Quality</th>
#       <th id="T_16e68_level0_col6" class="col_heading level0 col6" >Score</th>
#       <th id="T_16e68_level0_col7" class="col_heading level0 col7" >Difference</th>
#       <th id="T_16e68_level0_col8" class="col_heading level0 col8" >Color</th>
#       <th id="T_16e68_level0_col9" class="col_heading level0 col9" >Shape</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e68_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_16e68_row0_col0" class="data row0 col0" >1997-07-06 00:00:00</td>
#       <td id="T_16e68_row0_col1" class="data row0 col1" >506</td>
#       <td id="T_16e68_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_16e68_row0_col3" class="data row0 col3" >1.915208</td>
#       <td id="T_16e68_row0_col4" class="data row0 col4" >0.679004</td>
#       <td id="T_16e68_row0_col5" class="data row0 col5" >50.611735</td>
#       <td id="T_16e68_row0_col6" class="data row0 col6" >31.453719</td>
#       <td id="T_16e68_row0_col7" class="data row0 col7" >-1.854628</td>
#       <td id="T_16e68_row0_col8" class="data row0 col8" >blue</td>
#       <td id="T_16e68_row0_col9" class="data row0 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_16e68_row1_col0" class="data row1 col0" >1997-07-14 00:00:00</td>
#       <td id="T_16e68_row1_col1" class="data row1 col1" >1874</td>
#       <td id="T_16e68_row1_col2" class="data row1 col2" >94</td>
#       <td id="T_16e68_row1_col3" class="data row1 col3" >4.835286</td>
#       <td id="T_16e68_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_16e68_row1_col5" class="data row1 col5" >47.156272</td>
#       <td id="T_16e68_row1_col6" class="data row1 col6" >45.622168</td>
#       <td id="T_16e68_row1_col7" class="data row1 col7" >-0.437783</td>
#       <td id="T_16e68_row1_col8" class="data row1 col8" >red</td>
#       <td id="T_16e68_row1_col9" class="data row1 col9" >circle</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_16e68_row2_col0" class="data row2 col0" >1997-07-15 00:00:00</td>
#       <td id="T_16e68_row2_col1" class="data row2 col1" >5916</td>
#       <td id="T_16e68_row2_col2" class="data row2 col2" >54</td>
#       <td id="T_16e68_row2_col3" class="data row2 col3" >2.977257</td>
#       <td id="T_16e68_row2_col4" class="data row2 col4" >5.615089</td>
#       <td id="T_16e68_row2_col5" class="data row2 col5" >58.913664</td>
#       <td id="T_16e68_row2_col6" class="data row2 col6" >71.712570</td>
#       <td id="T_16e68_row2_col7" class="data row2 col7" >2.171257</td>
#       <td id="T_16e68_row2_col8" class="data row2 col8" >green</td>
#       <td id="T_16e68_row2_col9" class="data row2 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_16e68_row3_col0" class="data row3 col0" >1997-07-20 00:00:00</td>
#       <td id="T_16e68_row3_col1" class="data row3 col1" >7530</td>
#       <td id="T_16e68_row3_col2" class="data row3 col2" >66</td>
#       <td id="T_16e68_row3_col3" class="data row3 col3" >1.987739</td>
#       <td id="T_16e68_row3_col4" class="data row3 col4" >8.313639</td>
#       <td id="T_16e68_row3_col5" class="data row3 col5" >53.048372</td>
#       <td id="T_16e68_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_16e68_row3_col7" class="data row3 col7" >-1.775282</td>
#       <td id="T_16e68_row3_col8" class="data row3 col8" >blue</td>
#       <td id="T_16e68_row3_col9" class="data row3 col9" >square</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_16e68_row4_col0" class="data row4 col0" >1997-07-29 00:00:00</td>
#       <td id="T_16e68_row4_col1" class="data row4 col1" >2180</td>
#       <td id="T_16e68_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_16e68_row4_col3" class="data row4 col3" >7.769746</td>
#       <td id="T_16e68_row4_col4" class="data row4 col4" >8.379915</td>
#       <td id="T_16e68_row4_col5" class="data row4 col5" >48.369688</td>
#       <td id="T_16e68_row4_col6" class="data row4 col6" >41.936399</td>
#       <td id="T_16e68_row4_col7" class="data row4 col7" >-0.806360</td>
#       <td id="T_16e68_row4_col8" class="data row4 col8" >green</td>
#       <td id="T_16e68_row4_col9" class="data row4 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_16e68_row5_col0" class="data row5 col0" >1997-08-08 00:00:00</td>
#       <td id="T_16e68_row5_col1" class="data row5 col1" >2894</td>
#       <td id="T_16e68_row5_col2" class="data row5 col2" >66</td>
#       <td id="T_16e68_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_16e68_row5_col4" class="data row5 col4" >9.161101</td>
#       <td id="T_16e68_row5_col5" class="data row5 col5" >50.899971</td>
#       <td id="T_16e68_row5_col6" class="data row5 col6" >59.682053</td>
#       <td id="T_16e68_row5_col7" class="data row5 col7" >0.968205</td>
#       <td id="T_16e68_row5_col8" class="data row5 col8" >blue</td>
#       <td id="T_16e68_row5_col9" class="data row5 col9" >square</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row6" class="row_heading level0 row6" >37</th>
#       <td id="T_16e68_row6_col0" class="data row6 col0" >1997-08-11 00:00:00</td>
#       <td id="T_16e68_row6_col1" class="data row6 col1" >4768</td>
#       <td id="T_16e68_row6_col2" class="data row6 col2" >60</td>
#       <td id="T_16e68_row6_col3" class="data row6 col3" >0.827355</td>
#       <td id="T_16e68_row6_col4" class="data row6 col4" >6.754864</td>
#       <td id="T_16e68_row6_col5" class="data row6 col5" >42.369445</td>
#       <td id="T_16e68_row6_col6" class="data row6 col6" >54.652823</td>
#       <td id="T_16e68_row6_col7" class="data row6 col7" >0.465282</td>
#       <td id="T_16e68_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_16e68_row6_col9" class="data row6 col9" >circle</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row7" class="row_heading level0 row7" >40</th>
#       <td id="T_16e68_row7_col0" class="data row7 col0" >1997-08-14 00:00:00</td>
#       <td id="T_16e68_row7_col1" class="data row7 col1" >2431</td>
#       <td id="T_16e68_row7_col2" class="data row7 col2" >18</td>
#       <td id="T_16e68_row7_col3" class="data row7 col3" >2.201921</td>
#       <td id="T_16e68_row7_col4" class="data row7 col4" >2.453724</td>
#       <td id="T_16e68_row7_col5" class="data row7 col5" >55.945355</td>
#       <td id="T_16e68_row7_col6" class="data row7 col6" >38.445867</td>
#       <td id="T_16e68_row7_col7" class="data row7 col7" >-1.155413</td>
#       <td id="T_16e68_row7_col8" class="data row7 col8" >nan</td>
#       <td id="T_16e68_row7_col9" class="data row7 col9" >triangle</td>
#     </tr>
#     <tr>
#       <th id="T_16e68_level0_row8" class="row_heading level0 row8" >41</th>
#       <td i

# %%
# 実行して表示
hasnull_index = df[df.isnull().sum(axis=1) > 0].index
hasnull_index
# Out:
# Index([ 1,  9, 10, 15, 24, 34, 37, 40, 41, 42, 44, 46, 47, 53, 67, 72, 73, 75,
#        83, 85, 88, 92, 93, 99],
#       dtype='int64')

# %%
# 'Width'から'Score'までの平均値を表示してください('Difference'は除く)。iloc, mean()を使います
df.iloc[:,3:8].mean()
# Out:
# Width          5.217348
# Height         5.169774
# Quality       50.006651
# Score         51.023810
# Difference     0.114685
# dtype: float64

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.iloc[:, 3:8].mean()</code>
# </details>

# %%
# 上記のデータをdictionaryに変換します
replace_dict = dict(df.iloc[:,3:8].mean())

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>replace_dict = dict(df.iloc[:, 3:8].mean()) # もしくはdf.iloc[:, 3:8].mean().to_dict()</code>
# </details>

# %%
# 実行して表示
replace_dict
# Out:
# {'Width': 5.2173476814359345,
#  'Height': 5.169773732749145,
#  'Quality': 50.00665144991883,
#  'Score': 51.023810088288705,
#  'Difference': 0.11468532032260471}

# %%
# replace_dictに, 'Color:'white', 'Shape':'ellipse'を追加してください
replace_dict['Color'] = 'white'
replace_dict['Shape'] = 'ellipse'

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>replace_dict['Color'] = 'white'</code><br>
#     <code>replace_dict['Shape'] = 'ellipse'</code>
# </details>

# %%
# 実行して表示
replace_dict
# Out:
# {'Width': 5.2173476814359345,
#  'Height': 5.169773732749145,
#  'Quality': 50.00665144991883,
#  'Score': 51.023810088288705,
#  'Difference': 0.11468532032260471,
#  'Color': 'white',
#  'Shape': 'ellipse'}

# %%
# fillnaを実行してください
df.fillna(replace_dict, inplace=True)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.fillna(replace_dict, inplace=True)</code>
# </details>

# %%
# 実行して表示
df.loc[hasnull_index]
# Out:
#          Date  Price  Quantity     Width    Height    Quality      Score  \
# 1  1997-07-06    506        16  1.915208  0.679004  50.611735  31.453719
# 9  1997-07-14   1874        94  4.835286  5.169774  47.156272  45.622168
# 10 1997-07-15   5916        54  2.977257  5.615089  58.913664  71.712570
# 15 1997-07-20   7530        66  1.987739  8.313639  53.048372  51.023810
# 24 1997-07-29   2180        27  7.769746  8.379915  48.369688  41.936399
# 34 1997-08-08   2894        66  5.217348  9.161101  50.899971  59.682053
# 37 1997-08-11   4768        60  0.827355  6.754864  42.369445  54.652823
# 40 1997-08-14   2431        18  2.201921  2.453724  55.945355  38.445867
# 41 1997-08-15   4063        61  7.274125  0.641278  41.359575  83.451574
# 42 1997-08-16   6307        37  5.217348  4.876773  59.215755  51.267272
# 44 1997-08-18   3263        73  5.736099  9.603458  50.006651  55.576744
# 46 1997-08-20    722        66  9.880067  8.328709  57.754727  56.379262
# 47 1997-08-21   1838        67  4.981437  5.169774  42.678913  57.031107
# 53 1997-08-27    888        59  1.193864  5.209595  48.745040  51.023810
# 67 1997-09-10   4513        22  2.355312  5.169774  55.363809  50.835544
# 72 1997-09-15   5985        13  3.472464  2.145170  50.006651  53.930947
# 73 1997-09-16   6354        84  7.945283  7.917093  54.312865  56.844951
# 75 1997-09-18   4239        69  0.558966  2.324704  53.509729  51.023810
# 83 1997-09-26   2854        53  9.868105  8.293788  41.282555  51.023810
# 85 1997-09-28   6035        72  5.217348  1.061134  49.753547  48.799655
# 88 1997-10-01   1702        77  2.610089  5.301368  51.472199  51.023810
# 92 1997-10-05   8057        60  5.927891  0.157152  50.006651  78.711269
# 93 1997-10-06   7691        11  5.859937  4.086629  50.006651  37.919143
# 99 1997-10-12   1578        77  9.868106  5.397452  56.472400  51.023810
#
#     Difference  Color     Shape
# 1    -1.854628   blue   ellipse
# 9    -0.437783    red    circle
# 10    2.171257  green   ellipse
# 15   -1.775282   blue    square
# 24   -0.806360  green   ellipse
# 34    0.968205   blue    square
# 37    0.465282  white    circle
# 40   -1.155413  white  triangle
# 41    3.345157    red   ellipse
# 42    0.126727  green    square
# 44    0.557674   blue  triangle
# 46    0.114685    red    circle
# 47    0.703111  green  triangle
# 53   -0.581410  green  triangle
# 67    0.083554  green  triangle
# 72    0.393095  green    square
# 73    0.684495  white  triangle
# 75    0.556003   blue    circle
# 83   -1.040172    red  triangle
# 85   -0.120035   blue    circle
# 88    1.233529  green    circle
# 92    2.871127   blue    square
# 93   -1.208086  green    circle
# 99    2.215901    red   ellipse

# %%
# 実行して表示
df.isnull().sum().sum()
# 1が表示されればOK
# Out:
# 0

# %%
# df['COL_NAME'].fillna(df['COL_NAME'].mean())を繰り返すという方法がもっともシンプルです

# %% [markdown]
# Exercise_22 : SimpleImputerを使って'Difference'のNaN(index=46)を中央値で補間してください

# %%
from sklearn.impute import SimpleImputer

# %%
# 実行して表示
# 'Difference'のmedianを確認
df.describe().loc['50%', 'Difference']
# 上記が不明な場合はdf.describe()から確認してください
# Out:
# 0.12672721124555

# %%
from re import S
# インスタンス（オブジェクトの作成）
median_imputer = SimpleImputer(strategy='median')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>median_imputer = SimpleImputer(strategy='median')</code>
# </details>

# %%
# fitとtransformを同時に行って、新しいカラム'Dif_Imputed'にその値を入れる
df['Dif_Imputed'] = median_imputer.fit_transform(df[['Difference']])

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df['Dif_Imputed'] = median_imputer.fit_transform(df[['Difference']])</code>
# </details>

# %%
# 実行して表示　0.13770...
df.loc[46, 'Dif_Imputed']
# Out:
# 0.11468532032260471

# %% [markdown]
# ## 以上
